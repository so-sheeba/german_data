# %%
import pandas

# %%
import numpy as np

# %%
german = pandas.read_table('german.data.txt', delim_whitespace=True, names=["Status","Month","Credit","Purpose",
                                                                           "CreditAMT",
                                                                           "Savings", "Employment", "Installment",
                                                                           "SexMarital", "Position", "Residence",
                                                                           "Property", "Age", "OtherInstallment",
                                                                           "Housing", "ExistCredits", "Job",
                                                                           "Liability", "Phone", "Foreign", "Predict"])

# %%
german.head(10)
# Out:
#   Status  Month Credit Purpose  CreditAMT Savings Employment  Installment  \
# 0    A11      6    A34     A43       1169     A65        A75            4
# 1    A12     48    A32     A43       5951     A61        A73            2
# 2    A14     12    A34     A46       2096     A61        A74            2
# 3    A11     42    A32     A42       7882     A61        A74            2
# 4    A11     24    A33     A40       4870     A61        A73            3
# 5    A14     36    A32     A46       9055     A65        A73            2
# 6    A14     24    A32     A42       2835     A63        A75            3
# 7    A12     36    A32     A41       6948     A61        A73            2
# 8    A14     12    A32     A43       3059     A64        A74            2
# 9    A12     30    A34     A40       5234     A61        A71            4
#
#   SexMarital Position   ...    Property Age  OtherInstallment Housing  \
# 0        A93     A101   ...        A121  67              A143    A152
# ...

# %%
import pandas as pd

# %%
pd.value_counts(german['Predict'].values, sort=False)
# Out:
# 1    700
# 2    300
# dtype: int64
